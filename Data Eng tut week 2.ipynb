# %%
print("Hello BDA")
# Out:
# Hello BDA

# %%
import pandas as pd
import requests
import json

# %%
csv_url = '/content/boston_house_prices.csv'
df_csv = pd.read_csv(csv_url, skiprows=1)
print("First Few rows of the CSV Data:")
print(df_csv.head())
# Out:
# First Few rows of the CSV Data:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
# Excel
excel_url = '/content/Employee Data.xlsx'
df_excel = pd.read_excel(excel_url)
print("Last Few rows of the Excel Data:")
print(df_excel.tail())
# Out:
# Last Few rows of the Excel Data:
#        EEID       Job Title  Department        Business Unit  Gender  \
# 995  E03094     Sr. Analyst   Marketing  Speciality Products    Male
# 996  E01909         Analyst     Finance  Speciality Products  Female
# 997  E04398        Director   Marketing  Speciality Products    Male
# 998  E02521     Sr. Analyst     Finance  Speciality Products  Female
# 999  E03545  Vice President  Accounting            Corporate  Female
#
#      Ethnicity  Age  Hire Date  Annual Salary  Bonus %        Country  \
# 995  Caucasian   33 2016-09-18          98427     0.00  United States
# 996      Asian   44 2010-05-31          47387     0.00          China
# 997      Asian   31 2019-06-10         176710     0.15  United States
# 998      Asian   33 2012-01-28          95960     0.00          China
# 999      Asian   63 2020-07-26         216195     0.31  United States
#
#          City  Exit Date
# 995  Columbus        NaT
# 996   Chengdu 2018-01-08
# 997     Miami        NaT
# 998   Chengdu        NaT
# 999     Miami        NaT

# %%
# TXT
txt_url = 'https://www.gutenberg.org/files/1342/1342-0.txt'
response = requests.get(txt_url)
txt_data = response.text
print("First 200 characters of the TXT Data:")
print(txt_data[:200]) # Print first 200 characters
# Out:
# First 200 characters of the TXT Data:
# *** START OF THE PROJECT GUTENBERG EBOOK 1342 ***
#
#
#
#
#                             [Illustration:
#
#                              GEORGE ALLEN
#                                PUBLISHER

# %%
#JSON
#Opening JSON file
f = open('/content/sample_users_with_id.json')
# returns JSON object as a dictionary
data = json.load(f)
#Iterating through JSON
given_names = [user["given_name"] for user in data if "given_name" in user]
# print the names
print(given_names)
#closing file
f.close()
# Out:
# ['Hello', 'Hello1', 'John', 'Jane', 'Dummy']

# %%
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read csv files
df_BP = pd.read_csv('/content/BUSINESS-PROCESS.csv')
df_TD = pd.read_csv('/content/timedim.csv')
df_PR = pd.read_csv('/content/phonerate.csv')
df_LO = pd.read_csv('/content/location.csv')

# %%
#connect to database
conn = sqlite3.connect("DEdb")
cur = conn.cursor()

# %%
#load dataframes into database as tables with names BP,TD,PR,LO
df_BP.to_sql("BP", conn)
df_TD.to_sql("DT",conn)
df_PR.to_sql('PR',conn)
df_LO.to_sql('LO',conn)
# Out:
# 1500

# %%
# print all data of the BP tables
BP = pd.read_sql('SELECT * FROM BP', conn)
BP
# Out:
#       index  ID_time  ID_phoneRate  ID_location_Caller  ID_location_Receiver  \
# 0         0        3             1                 877                   757
# 1         1        3             1                 878                   758
# 2         2        3             1                 879                   759
# 3         3        3             1                 880                   760
# 4         4        3             1                 881                   761
# ...     ...      ...           ...                 ...                   ...
# 7803   7803       30             5                 910                   790
# 7804   7804       30             5                 911                   791
# 7805   7805       30             5                 912                   792
# 7806   7806       30             5                 913                   793
# 7807   7807       30             5                 914                   794
#
#       Price  NumberOfCalls
# 0     15250             48
# 1     15250             48
# 2     15250             48
# 3     15250             48
# 4     15250             48
# ...     ...            ...
# 7803  50400             72
# 7804  50400             72
# 7805  50400             72
# 7806  50400             72
# 7807  50400             72
#
# [7808 rows x 7 columns]

# %%
#see all data from DT table
TD = pd.read_sql('SELECT * FROM DT', conn)
TD
# Out:
#     index  ID_time        DayofWeek DateMonth  DateYear
# 0       0        1  tuesday            Jul-03      2003
# 1       1        2  wednesday          Jul-03      2003
# 2       2        3  thursday           Jul-03      2003
# 3       3        4  friday             Jul-03      2003
# 4       4        5  saturday           Jul-03      2003
# 5       5        6  friday             Aug-03      2003
# 6       6        7  saturday           Aug-03      2003
# 7       7        8  sunday             Aug-03      2003
# 8       8        9  monday             Aug-03      2003
# 9       9       10  tuesday            Aug-03      2003
# 10     10       11  wednesday          Oct-03      2003
# 11     11       12  thursday           Oct-03      2003
# 12     12       13  friday             Oct-03      2003
# 13     13       14  saturday           Oct-03      2003
# 14     14       15  sunday             Oct-03      2003
# 15     15       16  thursday           Jul-04      2004
# 16     16       17  friday             Jul-04      2004
# 17     17       18  saturday           Jul-04      2004
# 18     18       19  sunday             Jul-04      2004
# 19     19       20  monday             Jul-04      2004
# 20     20       21  sunday             Aug-04      2004
# 21     21       22  monday             Aug-04      2004
# 22     22       23  tuesday            Aug-04      2004
# 23     23       24  wednesday          Aug-04      2004
# 24     24       25  thursday           Aug-04      2004
# 25     25       26  friday             Oct-04      2004
# 26     26       27  saturday           Oct-04      2004
# 27     27       28  sunday             Oct-04      2004
# 28     28       29  monday             Oct-04      2004
# 29     29       30  tuesday            Oct-04      2004

# %%
#see all data from  PR table
PR = pd.read_sql('SELECT * FROM PR', conn)
PR
# Out:
#    index  ID_phoneRate phoneRateType
# 0      0             1         Notte
# 1      1             2        Giorno
# 2      2             3       Mattino
# 3      3             4  24 ore su 24
# 4      4             5   CartaNatale
# 5      5             6       Festivi
# 6      6             7      Business

# %%
#see all data from LO table
LO = pd.read_sql('SELECT * FROM LO', conn)
LO
# Out:
#       index  ID_location       City              Province  \
# 0         0          244   Citta439  Provincia30
# 1         1          245   Citta440  Provincia30
# 2         2          246   Citta441  Provincia30
# 3         3          247   Citta442  Provincia30
# 4         4          248   Citta443  Provincia30
# ...     ...          ...        ...                   ...
# 1495   1495         1084  Citta1448  Provincia97
# 1496   1496         1085  Citta1449  Provincia97
# 1497   1497         1086  Citta1450  Provincia97
# 1498   1498         1087  Citta1451  Provincia97
# 1499   1499         1088  Citta1452  Provincia97
#
#                     Region
# 0     Regione3
# 1     Regione3
# 2     Regione3
# 3     Regione3
# 4     Regione3
# ...                    ...
# 1495  Regione10
# 1496  Regione10
# 1497  Regione10
# 1498  Regione10
# 1499  Regione10
#
# [1500 rows x 5 columns]

# %%
import requests
import json
#API Documentation: https://openweathermap.org/current

# %%
currentweather = requests.get('https://api.openweathermap.org/data/2.5/weather?q=London&appid=b29954cc60e659dc3ea53752ae96aba4')
print(currentweather.status_code)
print(currentweather.json())
# Out:
# 200
# {'coord': {'lon': -0.1257, 'lat': 51.5085}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 285.45, 'feels_like': 284.9, 'temp_min': 284.55, 'temp_max': 286.01, 'pressure': 1003, 'humidity': 83, 'sea_level': 1003, 'grnd_level': 999}, 'visibility': 10000, 'wind': {'speed': 5.14, 'deg': 100}, 'clouds': {'all': 99}, 'dt': 1728194545, 'sys': {'type': 2, 'id': 2075535, 'country': 'GB', 'sunrise': 1728194982, 'sunset': 1728235625}, 'timezone': 3600, 'id': 2643743, 'name': 'London', 'cod': 200}

# %%
#save the JSON data to a file
with open('ForecastData.json', 'w') as file:
  json.dump(data, file, indent=4)

# %%
mkdir"DE_WK_2"

# %%
pwd:
# Out:
# '/content'

# %%
cd DE_WK_2
# Out:
# /content/DE_WK_2

# %%
ls
